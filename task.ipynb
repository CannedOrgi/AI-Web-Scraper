# %%
from flair.models import SequenceTagger
from flair.data import Sentence


tagger = SequenceTagger.load('ner')
def extract_person_names(text,company,url):
    try:
        sentence = Sentence(text)
        tagger.predict(sentence)
        person_names = set(entity.text for entity in sentence.get_spans('ner') if entity.tag == 'PER')
        print(f'Done for company {company} and webpage {url}')
        ans =  list(person_names)

        ans = [s.replace(company, "") for s in ans]
        return ans
    except Exception as e:
        print(e)

        return []
# Out:
# 2024-08-29 20:10:04,519 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>

# %%
import requests
from bs4 import BeautifulSoup
import os
from PyPDF2 import PdfReader
from urllib.parse import urlparse

def extract_text(web_url, company):
    try:
        if web_url.lower().endswith('.pdf'):
            pdf_filename = os.path.basename(urlparse(web_url).path)
            
            if not os.path.exists('documents'):
                os.makedirs('documents')
            
            pdf_filepath = os.path.join('documents', pdf_filename)
            
            response = requests.get(web_url)
            with open(pdf_filepath, 'wb') as f:
                f.write(response.content)
            
            with open(pdf_filepath, 'rb') as f:
                reader = PdfReader(f)
                text = ""
                for page in reader.pages:
                    text += page.extract_text()
            
            print(f'Done for {web_url}')
            return text

        else:
            response = requests.get(web_url)
            soup = BeautifulSoup(response.content, 'html.parser')
            text = soup.get_text()
            print(f'Done for {web_url}')
            return text

    except Exception as e:
        print(f'Failed at {web_url} and {company}: {str(e)}')

# %%
import requests
from bs4 import BeautifulSoup

def google_search(query,num):
    # Encode the query string for the URL
    query = query.replace(' ', '+')
    url = f"https://www.google.com/search?q={query}?num={num}"

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status() 

    soup = BeautifulSoup(response.text, 'html.parser')

    links = []
    for item in soup.find_all('div', class_='yuRUbf'):
        a_tag = item.find('a')
        if a_tag and a_tag.get('href'):
            links.append(a_tag['href'])

    return links

# %%
company = input('Enter Company Name')

query = f'{company} UK Testimonials'

company_testimonials = google_search(query,10)
company_testimonials
# Out:
# ['https://www.trustpilot.com/review/www.barclays.co.uk',
#  'https://www.barclayscorporate.com/client-experience/client-stories/',
#  'https://www.reviews.io/company-reviews/store/barclays',
#  'https://www.barclays.co.uk/business-banking/business-insight/feedback-economy/',
#  'https://www.glassdoor.co.in/Reviews/Barclays-Reviews-E3456.htm',
#  'https://www.ib.barclays/investment-banking/client-stories.html',
#  'https://www.glassdoor.co.uk/Reviews/Barclays-Reviews-E3456.htm',
#  'https://www.salesforce.com/uk/customer-success-stories/barclays/',
#  'https://www.tripadvisor.com/ShowUserReviews-g190762-d21340132-r935930825-Barclays_Bank_Building-Wolverhampton_West_Midlands_England.html',
#  'https://home.barclays/who-we-are/']

# %%
import concurrent.futures

company_testimonials = [{
    'company':company,
    'web_url': company_testimonials
}]
def process_testimonial(comp):
    company = comp['company']
    web_sites = []
    for url in comp['web_url']:
        text = extract_text(url, company) 

        if text:
            web_sites.append({'company': company, 'web_content': str(text),'url':url})
    return web_sites

all_web_sites = []

with concurrent.futures.ThreadPoolExecutor() as executor:
    results = executor.map(process_testimonial, company_testimonials)

    for result in results:
        all_web_sites.extend(result)
# Out:
# Done for https://www.trustpilot.com/review/www.barclays.co.uk
# Done for https://www.barclayscorporate.com/client-experience/client-stories/
# Done for https://www.reviews.io/company-reviews/store/barclays
# Done for https://www.barclays.co.uk/business-banking/business-insight/feedback-economy/
# Done for https://www.glassdoor.co.in/Reviews/Barclays-Reviews-E3456.htm
# Done for https://www.ib.barclays/investment-banking/client-stories.html
# Done for https://www.glassdoor.co.uk/Reviews/Barclays-Reviews-E3456.htm
# Done for https://www.salesforce.com/uk/customer-success-stories/barclays/
# Done for https://www.tripadvisor.com/ShowUserReviews-g190762-d21340132-r935930825-Barclays_Bank_Building-Wolverhampton_West_Midlands_England.html
# Done for https://home.barclays/who-we-are/

# %%
row_list = []

def process_website(part):
    try:
        text = part['web_content']
        company = part['company']
        url = part['url']
        names = extract_person_names(text,company,url)
        
        return [{'Name': name, 'Company': company,'Testimonial Page':url} for name in names]
    except:
        print(names)
        return []

for web_site in all_web_sites:
    result = process_website(web_site)
    row_list.extend(result)
# Out:
# Done for company Barclays and webpage https://www.trustpilot.com/review/www.barclays.co.uk
# Done for company Barclays and webpage https://www.barclayscorporate.com/client-experience/client-stories/
# Done for company Barclays and webpage https://www.reviews.io/company-reviews/store/barclays
# Done for company Barclays and webpage https://www.barclays.co.uk/business-banking/business-insight/feedback-economy/
# Done for company Barclays and webpage https://www.glassdoor.co.in/Reviews/Barclays-Reviews-E3456.htm
# Done for company Barclays and webpage https://www.ib.barclays/investment-banking/client-stories.html
# Done for company Barclays and webpage https://www.glassdoor.co.uk/Reviews/Barclays-Reviews-E3456.htm
# Done for company Barclays and webpage https://www.salesforce.com/uk/customer-success-stories/barclays/
# Done for company Barclays and webpage https://www.tripadvisor.com/ShowUserReviews-g190762-d21340132-r935930825-Barclays_Bank_Building-Wolverhampton_West_Midlands_England.html
# Done for company Barclays and webpage https://home.barclays/who-we-are/

# %%
len(row_list)
# Out:
# 81

# %%
row_list
# Out:
# [{'Name': 'Marcelo',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.trustpilot.com/review/www.barclays.co.uk'},
#  {'Name': 'Sneha',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.trustpilot.com/review/www.barclays.co.uk'},
#  {'Name': 'Sneha Bhambhani',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.trustpilot.com/review/www.barclays.co.uk'},
#  {'Name': 'Diane',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.trustpilot.com/review/www.barclays.co.uk'},
#  {'Name': 'Diane Drew',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.trustpilot.com/review/www.barclays.co.uk'},
#  {'Name': 'Hakim',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.trustpilot.com/review/www.barclays.co.uk'},
#  {'Name': 'Hossein Zaimi',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Adrian Beidas',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Aamir Khan   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Manuel Esteve',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Jonathon Traer-Clark',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Marie Freier',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Reid Marsh',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Aamir Khan',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Duncan Connellan',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Mani Joseph',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Naohiko Baba    ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Tim Devine',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'David King',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Raymond Yu   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Tim Devine   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Keith Robinson',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Pedro Costa',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Carrie Chen',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Duncan Beattie',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Adrian Beidas   Daniel Hanna',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Denise Wong',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Denise Wong   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Anthony Samengo-Turner',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'David Garner',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'David MacGown',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Marie Freier    ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Jeff Ammerman   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Florent Rodier',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Bronson Albery',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Sven Baumann',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Jim Rossman',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'David Garner   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Isabelle Millat',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Keith Robinson   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Arif Vohra',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Graham Warner',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Rafael Abati',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Isabelle Millat   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Arif Vohra ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'David King   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Alexander Altmann   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Angela Liu   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Robin Hood',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Jim Rossman',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Jean-Baptiste Patois',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Raymond Yu',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Jonathon Traer-Clark   Stephen Stewart',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Lucy Demery',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Geoffrey Belsher   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Ryan Voegeli',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Alishba Ali   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Arif Vohra',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Ian Woods',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Florent Rodier',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Christopher Ludwig',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Abhay Kumar Sinha',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Alexis de Rosnay',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Ed Skilton',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Angela Liu',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Rafael Abati   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Gautam Chawla',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Jeff Ammerman',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Hossein Zaimi   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Tim Main',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Michael Del Giudice   ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Corinne Grain',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Alexander Altmann',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Anthony Samengo-Turner   Relief',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Naohiko Baba ',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Bronson Albery',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Geoffrey Belsher',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Michael Del Giudice',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.ib.barclays/investment-banking/client-stories.html'},
#  {'Name': 'Jackie Uhi',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.salesforce.com/uk/customer-success-stories/barclays/'},
#  {'Name': 'Sidney Wager',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.salesforce.com/uk/customer-success-stories/barclays/'},
#  {'Name': 'Steve Weston',
#   'Company': 'Barclays',
#   'Testimonial Page': 'https://www.salesforce.com/uk/customer-success-stories/barclays/'}]

# %%
import pandas as pd

df = pd.DataFrame(row_list)

# %%
for index,row in df.iterrows():
    try:
        name = row['Name']
        query = f'{name} UK profile linkedin'
        link = google_search(query,1)[0]
        df.at[index,'Linkedin Profile'] = link
        print(f'Done for index {index}')
    except Exception as e:
        print(e)
        pass
# Out:
# Done for index 0
# Done for index 1
# Done for index 2
# Done for index 3
# Done for index 4
# Done for index 5
# Done for index 6
# Done for index 7
# Done for index 8
# Done for index 9
# Done for index 10
# Done for index 11
# Done for index 12
# Done for index 13
# Done for index 14
# Done for index 15
# Done for index 16
# Done for index 17
# Done for index 18
# Done for index 19
# Done for index 20
# Done for index 21
# Done for index 22
# Done for index 23
# Done for index 24
# Done for index 25
# Done for index 26
# Done for index 27
# Done for index 28
# Done for index 29
# Done for index 30
# Done for index 31
# Done for index 32
# Done for index 33
# ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Done for index 35
# Done for index 36
# Done for index 37
# Done for index 38
# Done for index 39
# Done for index 40
# Done for index 41
# Done for index 42
# Done for index 43
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DArif%2BVohra%2B%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GNSvsLYGIjB_Dm6fVy02frDdZO-LTQjKCaRgkUqaUD5lLwx_IV7zXfzAKrbCmU3JjXXqw45-M0oyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DDavid%2BKing%2B%2B%2B%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GNWvsLYGIjCg7SyD7oWi3CSLElVtRJu2mFYx8Q_uMIc75e649GKrFtptLlENCzAnmolf69HBPkcyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DAlexander%2BAltmann%2B%2B%2B%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GNevsLYGIjBf7ZHy9z7ktrCVts6pSemw4dypX_nwPrPYoi9YlUUhEJ48EdZVT-YLsaJtHinSsqIyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DAngela%2BLiu%2B%2B%2B%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GNivsLYGIjCLk4oLYmBfdN-ySp7H9lf81dgK8Sd7Xtm1ofUsJTcqLT1X7TIZxBuoUwQQITDvnRoyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DRobin%2BHood%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GNmvsLYGIjACCHMsy9jjQfdA4mOtSLAnNcug05MbQ9-yS0XmYmMMcc9cCQQPs1GTVzDqL1e-35AyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DJim%2BRossman%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GNqvsLYGIjA217WEiTbEt6LIGmHwXTR-KDlFqkoc7NvNVrik30JtSKm5Kov1CnCemBplrzL4crIyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DJean-Baptiste%2BPatois%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6
2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GO2vsLYGIjAenQb-hPlWkQRTKAm4lwJ6y17mXlqYZecxq4Twh6qox2tkseDcGcsl1chriDjFTrsyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DTim%2BMain%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GO6vsLYGIjDBsk-xRh9-2flvAROuPdMobeqC2hDscfHG8uS-y8kWwK1aljaerocbNsLbeXPJmMwyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DMichael%2BDel%2BGiudice%2B%2B%2B%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GO-vsLYGIjCii42LURSNPqJq9QHjFZul3tSHt8OvsAk08sUztUXRzbl8Rin-l7M1DYEzUIvoz9MyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DCorinne%2BGrain%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GPGvsLYGIjDvuJM739kby6Bap7u9Vx_PeYlSvxpy4yz-ZI9Xyq-Ilz9iJyHBewMuPKnTu43fpCQyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DAlexander%2BAltmann%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GPKvsLYGIjABv4tpUAuRK2tVEd7qKX3hdaGd5oJ4pHqAL7l-LBXjgvZTOATlDY0i9YF5pm1hrNoyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DAnthony%2BSamengo-Turner%2B%2B%2BRelief%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GPOvsLYGIjCgEGKdQjQ_P5LcmxVZGza-B5cqG_WXscQDQ8i7jB3-BnvrSS8r1_J5spEp6vi4vfcyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DNaohiko%2BBaba%2B%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GPSvsLYGIjDy4tXPDjX99OrNmqbvbT9mmCYs9lIxt8oB3jq5E_LcxonKAsVhgiwYsMMWR4mYvKMyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DBronson%2BAlbery%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GPWvsLYGIjAEilur8QvLFJdJcY7YUyjpkmYWa5328leBJlFLDVIHzXGDDtWb3_9Ui70hLmL9Dc4yAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DGeoffrey%2BBelsher%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GPavsLYGIjASj3yXWY052gSgay_gbjxvajQBbRJf2sJpAY3ST86FfEaWPuaq5u1lkGYe2dbhFWgyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DMichael%2BDel%2BGiudice%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GPevsLYGIjD473KurYpOQFQt0Ev77imt4ANYM2rDIP4BN-sEaO4GiT5NcKk3zaWLh3poJs45d1IyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DJackie%2BUhi%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GPivsLYGIjB-fVdPeVEN2NPXKiZXozjiplfRPVnEGaza_rA3cv1mlPvekdXEFkkj0JKjLeoh-z0yAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DSidney%2BWager%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GPmvsLYGIjAeAkLiJrHsUgd4xz49ILhKWpfBVnK57_qletw1OjaoB0h-uHEky5ZV03UEQqOpSZcyAXJaAUM
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DSteve%2BWeston%2BUK%2Bprofile%2Blinkedin%3Fnum%3D1&q=EgQOi8S6GPqvsLYGIjBNIRKdzwUSk8yJ8Mq7YSmy-Va8x1i8EUsGYvL59KdkUie_QN3QjJgZZrHMn0clYEUyAXJaAUM

# %%
df.to_excel('Updated_list.xlsx',index=False)

# %%
import openpyxl
from openpyxl.utils import get_column_letter

def convert_urls_to_hyperlinks(excel_file, sheet_name, url_column):
    workbook = openpyxl.load_workbook(excel_file)
    sheet = workbook[sheet_name]

    col_letter = get_column_letter(url_column)

    for row in range(2, sheet.max_row + 1): 
        cell = sheet[f"{col_letter}{row}"]
        if isinstance(cell.value, str) and cell.value.startswith("http"):
            sheet[f"{col_letter}{row}"].hyperlink = cell.value
            sheet[f"{col_letter}{row}"].value = 'Link'
            sheet[f"{col_letter}{row}"].style = "Hyperlink"

    workbook.save(excel_file)

excel_file = 'Updated_list.xlsx'
sheet_name = "Sheet1"
url_column = 3  

convert_urls_to_hyperlinks(excel_file, sheet_name, url_column)
url_column = 4
convert_urls_to_hyperlinks(excel_file, sheet_name, url_column)
